# %%
import pandas as pd

# %%
titanic_df = pd.read_csv('train.csv', sep = ',')
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # 1. Діти першого класу, які врятувалися.

# %%
df_age = titanic_df["Age"] <= 14 
df_survived = titanic_df['Survived'] == 1
df_pclass = titanic_df['Pclass'] == 1
df[df_age & df_survived & df_pclass]
# Out:
#      PassengerId  Survived  Pclass                                 Name  \
# 305          306         1       1       Allison, Master. Hudson Trevor
# 435          436         1       1            Carter, Miss. Lucile Polk
# 445          446         1       1            Dodge, Master. Washington
# 802          803         1       1  Carter, Master. William Thornton II
#
#         Sex    Age  SibSp  Parch  Ticket      Fare    Cabin Embarked
# 305    male   0.92      1      2  113781  151.5500  C22 C26        S
# 435  female  14.00      1      2  113760  120.0000  B96 B98        S
# 445    male   4.00      0      2   33638   81.8583      A34        S
# 802    male  11.00      1      2  113760  120.0000  B96 B98        S

# %% [markdown]
# # 2. Максимальна кількість пасажирів різних класів і кількість людей, що вижили відповідно до класу

# %%
survived_plass_df = titanic_df[['Survived', 'Pclass']]      
survived_plass_df.head(11)
# Out:
#     Survived  Pclass
# 0          0       3
# 1          1       1
# 2          1       3
# 3          1       1
# 4          0       3
# 5          0       3
# 6          0       1
# 7          0       3
# 8          1       3
# 9          1       2
# 10         1       3

# %%
survived_by_pclass = survived_plass_df.groupby(['Pclass']).sum()
total_by_pclass = survived_plass_df.groupby(['Pclass']).count()

# %%
total_by_pclass.rename(columns = {'Survived':'Total'}, inplace = True)

# %%
survived_total_by_pclass = pd.merge(survived_by_pclass, total_by_pclass, left_index=True, right_index=True)
survived_total_by_pclass
# Out:
#         Survived  Total
# Pclass
# 1            136    216
# 2             87    184
# 3            119    491

# %% [markdown]
# # 3. Імовірність виживання чоловіка на кораблі

# %%
people = titanic_df[titanic_df['Age'] > 18]
people.iloc[:10]
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 6             7         0       1
# 8             9         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# ...

# %%
surviving_men = titanic_df[(titanic_df['Age'] > 18) & (titanic_df['Survived'] == 1) & (titanic_df['Sex'] == 'male')]
surviving_men.iloc[:10]
# Out:
#      PassengerId  Survived  Pclass  \
# 21            22         1       2
# 23            24         1       1
# 74            75         1       3
# 81            82         1       3
# 97            98         1       1
# 127          128         1       3
# 146          147         1       3
# 187          188         1       1
# 207          208         1       3
# 209          210         1       1
#
#                                               Name   Sex   Age  SibSp  Parch  \
# 21                           Beesley, Mr. Lawrence  male  34.0      0      0
# 23                    Sloper, Mr. William Thompson  male  28.0      0      0
# 74                                   Bing, Mr. Lee  male  32.0      0      0
# 81                     Sheerlinck, Mr. Jan Baptist  male  29.0      0      0
# 97                 Greenfield, Mr. William Bertram  male  23.0      0      1
# 127                      Madsen, Mr. Fridtjof Arne  male  24.0      0      0
# ...

# %%
people.shape[0]
# Out:
# 575

# %%
surviving_men.shape[0]
# Out:
# 69

# %%
men_chance_of_survival = surviving_men.shape[0] / people.shape[0]
men_chance_of_survival * 100
# Out:
# 12.0
